# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

columns = ['idx', 'Lx', 'Ly', 'Lw', 'Lh', 'Rx', 'Ry', 'Rw', 'Rh']
listed = [[2, 149, 87, 458, 312, 77, 117, 384, 343],
         [3, 146, 83, 463, 312, 72, 109, 384, 339],
         [4, 538, 82, 845, 320, 457, 111, 760, 345],
            [5, 188, 62, 576, 351, 102, 96, 478, 375],
            [6, 182, 47, 647, 381, 55, 74, 526, 407],
            [7, 143, 19, 685, 422, 7, 46, 541, 448]]
df = pd.DataFrame(listed, columns=columns)

# %%
def cm_disparity(x, y):
    disp = abs(x-y)
    return disp

def dist_formula(disparity):
    T = 2.6 # cm
    f = 0.315 # cm
    img_element = 0.0001*2.8 # cm
    K = int(T*f/img_element) # 2925
    dist = K/disparity
    return dist 

    
df["disparity"] = df.apply(lambda x : cm_disparity(x["Lw"], x["Rw"]), axis=1)
df['distance(z)'] = df['disparity'].apply(dist_formula)

fig, ax = plt.subplots()
x = np.array(df['disparity'])
y = np.array(df['distance(z)'])

ax.plot(x, y, label="test")
ax.set_xlabel('disparity')
ax.set_ylabel('distance(z)')
plt.show()

df
# Out:
#    idx   Lx  Ly   Lw   Lh   Rx   Ry   Rw   Rh  disparity  distance(z)
# 0    2  149  87  458  312   77  117  384  343       74.0    39.527027
# 1    3  146  83  463  312   72  109  384  339       79.0    37.025316
# 2    4  538  82  845  320  457  111  760  345       85.0    34.411765
# 3    5  188  62  576  351  102   96  478  375       98.0    29.846939
# 4    6  182  47  647  381   55   74  526  407      121.0    24.173554
# 5    7  143  19  685  422    7   46  541  448      144.0    20.312500
